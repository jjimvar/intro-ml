# %% [markdown]
# ## DUDAS

# %% [markdown]
# - Como podemos interpretar los valores de OOB_Score
# - Como cambiar accuracy por recall en OOB_Score
# - Booststrap en la optimización de parámetros
# - Diferencia entre GradientBoostingClassifier y XGBoostClassifier
# - Porque cuando guardo y descargo un modelo, me da una matriz de confusion distinta

# %% [markdown]
# -----

# %% [markdown]
# CAMBIOS LOGIT

# %%
#Estudio de seguros
def get_precision_recall_curve(X_train, y_train, estimator):
  # Dividir tus datos en conjuntos de entrenamiento y validación
  X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

  # Definir el modelo base (LGBM)
  model = estimator.fit(X_train, y_train)

  # Predecir probabilidades en el conjunto de prueba
  y_probs = model.predict_proba(X_val)[:, 1]  # Probabilidad para la clase positiva (compra)

  # Calcular y graficar
  precision, recall, thresholds = precision_recall_curve(y_val, y_probs)
  plt.figure(figsize=(8, 6))
  plt.plot(thresholds, precision[:-1], label="Precisión")
  plt.plot(thresholds, recall[:-1], label="Recall")
  plt.xlabel("Umbral de decisión")
  plt.ylabel("Métrica")
  plt.title("Curva Precision-Recall vs. Umbral de decisión")
  plt.legend()
  plt.show()
get_precision_recall_curve(X_train, y_train, m)

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import (precision_recall_curve,
                             PrecisionRecallDisplay)
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
X, y = make_classification(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=0)
clf = SVC(random_state=0)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
precision, recall, _ = precision_recall_curve(y_test, predictions)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %%
# Estadísticas descriptivas para cada grupo
    ds1 = smw.DescrStatsW(data1.dropna())
    ds2 = smw.DescrStatsW(data2.dropna())

    # Comparamos medias
    res = smw.CompareMeans(ds1, ds2)
    tStat, pVal, dfreedom = res.ttest_ind(alternative=alt, value=0, usevar=usevartype)

# %% [markdown]
# ---

# %% [markdown]
# CAMBIOS LOGIT
#
# - Proportion z test (no tenemos porque utilizar y) &rarr; y pq es el target
#
# - Con winsorización, standar scaler (no hay outliers) &rarr; comentar tabla resumen

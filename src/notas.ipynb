# %% [markdown]
# - Trabajar hiperparámetros de cada algoritmo
# - Regla de aplicación de cada tipo de escalado
# - train al instanciar el modelo¿?
# - Tratamiento de las variables correlaciones
# - Como visualizar hojas finales con arboles más profundos
# - Como determinar el numero minimo de hojas
# - Diferencia log_loss y entropy
# - como saber que parámetros optimizar

# %% [markdown]
# CAMBIOS LOGIT
#
# - Proportion z test (no tenemos porque utilizar y) &rarr; y pq es el target
#
# - Con winsorización, standar scaler (no hay outliers) &rarr; comentar tabla resumen

# %% [markdown]
# Investigar:
# - ``Feature Importance RF`` La forma en que se calcula depende del algoritmo: en árboles y bosques la importancia suele ser la reducción promedio del criterio de división (por ejemplo, disminución de Gini o reducción de la impuridad de entropía) atribuida a cada característica a lo largo de todas las divisiones del árbol. Por eso se le suele llamar "feature importance (impurity-based)". El vector suele estar normalizado para sumar 1, de modo que los valores son comparables entre características dentro del mismo modelo.
#
# - Metodos de selección de variables y vif
#
#
# - help (como Stata)

# %% [markdown]
# Dudas tutoría:
# - Tratamiento de outliers y missings: ¿antes
# - XGRegressor: definir o no dtype como categorica
# - ¿Cómo ordenamos feature en la tabla con los 3 resultados?
# - Tratamiento de outliers para poder evaluar que variables son mejores o peores a la hora de predecir

# %% [markdown]
# - Tratamiento de missing: eliminar poutcome, default y el resto.

# %% [markdown]
# CRIBADO
#
#
# 4. Eliminar filas con muchos datos faltantes
# 5. Codificar variables categóricas
# 6. Extraer características
# 7. División Train-Test
# 8. Imputar missing values
# 9. Analizar outliers

# %% [markdown]
# ----

# %% [markdown]
# Dudas:
# - Target Coding con variables categóricas (como agrupar categorías) --> test vara verificar que las categorias estan bien hechas.
#
# - ¿Como debemos tratar las diferentes variables categoricas (ordinales/ nominales)?
#
# ¿Podemos forzar nominales a ordinales con el uso de variables instrumentales (job-renta)
#
# - Descripción general

# %% [markdown]
# Mejoras:
#
# - Preprocesamiento de datos, visualización y categorización, train-test, tratamiento missing
#
# - Evaluación de categorias en logit &rarr; Medidas unitarias error (R2, MAPE)/

# %% [markdown]
# Importante ver diferentes tipos de seleccion de características

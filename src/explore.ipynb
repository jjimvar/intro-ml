# %% [markdown]
# Dudas:
# - datos sin reseñas
# - longitud y laltitud
# - antigüedad alojamiento
# - tratamiento outliers y missing values

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Hacer:
# - Alojamiento nuevo
# - Dia de la semana??
